# %%
import pandas as pd
import numpy as np
import os

# %%
df=pd.read_csv('datacleaning2.csv',names=('Name,Colour,Gender,Brand,Price,Offer,Ratings,No of Ratings,No of Reviews').split(','))
df
# Out:
#                                                   Name  \
# 0                                               Jutis
# 1                                CRYSTA Running Shoes
# 2                                       Walking Shoes
# 3                           Troy MU IDP Walking Shoes
# 4                                       Running Shoes
# ..                                                 ...
# 995                                           Casuals
# 996                                            Casual
# 997  Partywear And Casual Chukka Boots for Girls An...
# 998                                     Running Shoes
# 999  Easywalk-08 Running shoes for boys |sports sho...
#
#                                Colour Gender          Brand  Price  Offer  \
# 0                                Pink  Women     ['Gerief']    199    NaN
# 1                                Blue    Men     ['Campus']    786   25.0
# 2                               Black    Men         ['TR']    309    NaN
# ...

# %%
df.dtypes
# Out:
# Name              object
# Colour            object
# Gender            object
# Brand             object
# Price              int64
# Offer            float64
# Ratings          float64
# No of Ratings    float64
# No of Reviews    float64
# dtype: object

# %%
df['Price']=df['Price'].astype(int)

# %%
df['Offer']=df['Offer'].astype(float)

# %%
df['Ratings']=df['Ratings'].apply(float)

# %%
df['No of Ratings']=df['No of Ratings'].astype(float)

# %%
df['No of Reviews']=df['No of Reviews'].astype(float)

# %%
df.dtypes
# Out:
# Name              object
# Colour            object
# Gender            object
# Brand             object
# Price              int32
# Offer            float64
# Ratings          float64
# No of Ratings    float64
# No of Reviews    float64
# dtype: object

# %%
df
# Out:
#                                                   Name  \
# 0                                               Jutis
# 1                                CRYSTA Running Shoes
# 2                                       Walking Shoes
# 3                           Troy MU IDP Walking Shoes
# 4                                       Running Shoes
# ..                                                 ...
# 995                                           Casuals
# 996                                            Casual
# 997  Partywear And Casual Chukka Boots for Girls An...
# 998                                     Running Shoes
# 999  Easywalk-08 Running shoes for boys |sports sho...
#
#                                Colour Gender          Brand  Price  Offer  \
# 0                                Pink  Women     ['Gerief']    199    NaN
# 1                                Blue    Men     ['Campus']    786   25.0
# 2                               Black    Men         ['TR']    309    NaN
# ...

# %%
df['Price'].max()
# Out:
# 6294

# %%
df['Price'].min()
# Out:
# 178

# %%
d_1=df['Ratings'].value_counts().plot.bar()

# %%
d_1
# Out:
# <AxesSubplot:>

# %%
df.isnull()
# Out:
#       Name  Colour  Gender  Brand  Price  Offer  Ratings  No of Ratings  \
# 0    False   False   False  False  False   True    False          False
# 1    False   False   False  False  False  False    False          False
# 2    False   False   False  False  False   True    False          False
# 3    False   False   False  False  False  False    False          False
# 4    False   False   False  False  False  False    False          False
# ..     ...     ...     ...    ...    ...    ...      ...            ...
# 995  False   False   False  False  False  False    False          False
# 996  False   False   False  False  False  False    False          False
# 997  False   False   False  False  False   True    False          False
# 998  False   False   False  False  False  False    False          False
# 999  False   False   False  False  False  False    False          False
#
#      No of Reviews
# 0            False
# 1            False
# 2            False
# 3            False
# ...

# %%
df.isnull().sum()
# Out:
# Name               1
# Colour             0
# Gender             0
# Brand              0
# Price              0
# Offer            385
# Ratings            7
# No of Ratings      6
# No of Reviews      6
# dtype: int64

# %%
df.isnull().any()
# Out:
# Name              True
# Colour           False
# Gender           False
# Brand            False
# Price            False
# Offer             True
# Ratings           True
# No of Ratings     True
# No of Reviews     True
# dtype: bool

# %%
df['Brand'].describe()
# Out:
# count         1000
# unique         193
# top       ['Puma']
# freq           158
# Name: Brand, dtype: object

# %%
df['Brand']=df['Brand'].str.replace("[","")

# %%
df['Brand']=df['Brand'].str.replace("]","")

# %%
df['Brand']=df['Brand'].str.replace("'","")

# %%
df['Brand']
# Out:
# 0         Gerief
# 1         Campus
# 2             TR
# 3           Puma
# 4           Puma
#          ...
# 995     Woodland
# 996     Woodland
# 997    Commander
# 998      Camfoot
# 999        Asian
# Name: Brand, Length: 1000, dtype: object

# %%
df['Price'].describe()
# Out:
# count    1000.000000
# mean     1123.933000
# std       930.118859
# min       178.000000
# 25%       460.250000
# 50%       786.000000
# 75%      1449.750000
# max      6294.000000
# Name: Price, dtype: float64

# %%
df.loc[:,['No of Ratings','No of Reviews']].describe()
# Out:
#        No of Ratings  No of Reviews
# count     994.000000     994.000000
# mean     6697.013078     968.492958
# std     19777.819861    3037.141880
# min         3.000000       0.000000
# 25%       414.000000      61.000000
# 50%      1107.500000     161.000000
# 75%      5845.250000     803.000000
# max    244376.000000   38977.000000

# %%
df['Offer'].isnull().sum()
# Out:
# 385

# %%
df=df.dropna(subset=['Offer'])

# %%
df
# Out:
#                                                   Name          Colour Gender  \
# 1                                CRYSTA Running Shoes             Blue    Men
# 3                           Troy MU IDP Walking Shoes             Grey    Men
# 4                                       Running Shoes            Black    Men
# 5                      Gorunfocus Athos Walking Shoes     Grey, Orange    Men
# 7                      Propel 3D MU IDP Running Shoes             Blue    Men
# ..                                                 ...             ...    ...
# 993                                          Sneakers            White    Men
# 995                                           Casuals             Blue    Men
# 996                                            Casual            Brown    Men
# 998                                     Running Shoes            Green    Men
# 999  Easywalk-08 Running shoes for boys |sports sho...  Maroon, Maroon    Men
#
# ...

# %%
df.isnull().sum()
# Out:
# Name             0
# Colour           0
# Gender           0
# Brand            0
# Price            0
# Offer            0
# Ratings          4
# No of Ratings    3
# No of Reviews    3
# dtype: int64

# %%
df=df.dropna(subset=['Brand'])

# %%
df=df.dropna(subset=['Ratings'])

# %%
df=df.dropna(subset=['No of Ratings'])

# %%
df=df.dropna(subset=['No of Reviews'])

# %%
df=df.dropna(subset=['Name'])

# %%
df.isnull().sum()
# Out:
# Name             0
# Colour           0
# Gender           0
# Brand            0
# Price            0
# Offer            0
# Ratings          0
# No of Ratings    0
# No of Reviews    0
# dtype: int64

# %%
df
# Out:
#                                                   Name          Colour Gender  \
# 1                                CRYSTA Running Shoes             Blue    Men
# 3                           Troy MU IDP Walking Shoes             Grey    Men
# 4                                       Running Shoes            Black    Men
# 5                      Gorunfocus Athos Walking Shoes     Grey, Orange    Men
# 7                      Propel 3D MU IDP Running Shoes             Blue    Men
# ..                                                 ...             ...    ...
# 993                                          Sneakers            White    Men
# 995                                           Casuals             Blue    Men
# 996                                            Casual            Brown    Men
# 998                                     Running Shoes            Green    Men
# 999  Easywalk-08 Running shoes for boys |sports sho...  Maroon, Maroon    Men
#
# ...

# %%
df[(df["Brand"]=='ADIDAS') & (df['Gender']=='Men')]
# Out:
#                                    Name       Colour Gender   Brand  Price  \
# 360             EASY VULC 2.0 Sneakers         Black    Men  ADIDAS   2127
# 368         school shoes Running Shoes         Black    Men  ADIDAS    664
# 520           Kivaro 1 M Running Shoes          Grey    Men  ADIDAS   2488
# 541         Kyris 4.0 Ms Running Shoes          Blue    Men  ADIDAS   2041
# 608      STREETMIGHTY Basketball Shoes         White    Men  ADIDAS   3659
# 636            Advantage Base Sneakers         White    Men  ADIDAS   3049
# 735              Puaro Ms Running Shoe         Black    Men  ADIDAS   2350
# 737            Kyris 1 M Running Shoes   Black, Blue    Men  ADIDAS   2116
# 785                   PACE VS Sneakers         White    Men  ADIDAS   2479
# 818              Throb M Running Shoes         Black    Men  ADIDAS   1754
# 846           Helkin 3 M Running Shoes          Navy    Men  ADIDAS   1655
# ...

# %%
df[(df["Brand"]=='ADIDAS') & (df['Gender']=='Men')].count
# Out:
# <bound method DataFrame.count of                                    Name       Colour Gender   Brand  Price  \
# 360             EASY VULC 2.0 Sneakers         Black    Men  ADIDAS   2127
# 368         school shoes Running Shoes         Black    Men  ADIDAS    664
# 520           Kivaro 1 M Running Shoes          Grey    Men  ADIDAS   2488
# 541         Kyris 4.0 Ms Running Shoes          Blue    Men  ADIDAS   2041
# 608      STREETMIGHTY Basketball Shoes         White    Men  ADIDAS   3659
# 636            Advantage Base Sneakers         White    Men  ADIDAS   3049
# 735              Puaro Ms Running Shoe         Black    Men  ADIDAS   2350
# 737            Kyris 1 M Running Shoes   Black, Blue    Men  ADIDAS   2116
# 785                   PACE VS Sneakers         White    Men  ADIDAS   2479
# 818              Throb M Running Shoes         Black    Men  ADIDAS   1754
# 846           Helkin 3 M Running Shoes          Navy    Men  ADIDAS   1655
# ...

# %%
df[(df["Brand"]=='ADIDAS') & (df['Gender']=='Men')].describe()
# Out:
#              Price      Offer    Ratings  No of Ratings  No of Reviews
# count    15.000000  15.000000  15.000000      15.000000      15.000000
# mean   2119.600000  48.733333   4.140000    1045.866667     129.933333
# std     720.467685  11.048378   0.222967    2290.766898     283.652319
# min     664.000000  35.000000   3.500000       5.000000       1.000000
# 25%    1704.500000  39.000000   4.100000      46.000000       9.000000
# 50%    2116.000000  46.000000   4.100000     264.000000      40.000000
# 75%    2483.500000  55.000000   4.250000     442.000000      51.000000
# max    3659.000000  73.000000   4.400000    8512.000000    1033.000000

# %%
dfw = pd.DataFrame(df)
  
# saving the dataframe 
dfw.to_csv('dataploting.csv', header=False, index=False)

# %%
df
# Out:
#                                                   Name          Colour Gender  \
# 1                                CRYSTA Running Shoes             Blue    Men
# 3                           Troy MU IDP Walking Shoes             Grey    Men
# 4                                       Running Shoes            Black    Men
# 5                      Gorunfocus Athos Walking Shoes     Grey, Orange    Men
# 7                      Propel 3D MU IDP Running Shoes             Blue    Men
# ..                                                 ...             ...    ...
# 993                                          Sneakers            White    Men
# 995                                           Casuals             Blue    Men
# 996                                            Casual            Brown    Men
# 998                                     Running Shoes            Green    Men
# 999  Easywalk-08 Running shoes for boys |sports sho...  Maroon, Maroon    Men
#
# ...
